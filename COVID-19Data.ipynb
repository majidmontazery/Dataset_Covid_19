# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Covid_Date = pd.read_csv(r'C:/Users/HIGH COMP/Downloads/exercise_files (1)/exercise_files/Covide-Dataset.csv')

# %%
Covid_Date.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
Covid_Date.dtypes
# Out:
# Date         object
# State        object
# Region       object
# Confirmed     int64
# Deaths        int64
# Recovered     int64
# dtype: object

# %%
Covid_Date.shape
# Out:
# (321, 6)

# %%
Covid_Date.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
Covid_Date.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
sns.heatmap(Covid_Date.isnull())
plt.show()

# %%
Covid_Date.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
Covid_Date.groupby('Region').sum().head(20)
# Out:
# C:\Users\HIGH COMP\AppData\Local\Temp\ipykernel_11828\638136486.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Covid_Date.groupby('Region').sum().head(20)
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# ...

# %%
Covid_Date.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
Covid_Date.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# C:\Users\HIGH COMP\AppData\Local\Temp\ipykernel_11828\3714530067.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Covid_Date.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
Covid_Date = Covid_Date[~(Covid_Date.Confirmed < 10)]

# %%
#Covid_Date.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %%
Covid_Date.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
Covid_Date.groupby('Region').Deaths.sum().sort_values(ascending =True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %%
Covid_Date[Covid_Date.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
Covid_Date[Covid_Date.Region == 'US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
Covid_Date[Covid_Date.Region == 'Yemen']
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %%
Covid_Date.sort_values(by = ['Confirmed'],ascending=True).head(50)
# Out:
#           Date                         State  \
# 156  4/29/2020                           NaN
# 70   4/29/2020                           NaN
# 59   4/29/2020                           NaN
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 256  4/29/2020                    Montserrat
# 144  4/29/2020                           NaN
# 27   4/29/2020                           NaN
# 306  4/29/2020      Turks and Caicos Islands
# 118  4/29/2020                           NaN
# 215  4/29/2020                Grand Princess
# 206  4/29/2020   Falkland Islands (Malvinas)
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 114  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 260  4/29/2020                 New Caledonia
# ...

# %%
Covid_Date.sort_values(by=['Recovered'],ascending=False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 78   4/29/2020              NaN               Ireland      20253    1190
# 8    4/29/2020              NaN               Austria      15402     580
# 107  4/29/2020              NaN                Mexico      17799    1732
# ...

# %%
data = stats.poisson.rvs(size=200, mu=10,loc=20)
print(data)
# Out:
# [28 28 33 30 30 29 27 30 29 28 24 27 38 31 31 32 29 31 23 25 35 30 29 25
#  30 32 32 33 34 30 27 26 29 31 29 32 36 29 33 29 31 27 30 33 24 33 34 34
#  32 27 29 30 33 31 24 29 28 27 32 27 32 35 30 27 31 31 33 32 32 24 29 29
#  30 27 32 29 31 28 34 28 35 34 28 23 28 30 31 32 28 28 25 31 29 30 31 28
#  30 31 37 34 26 28 24 35 30 29 36 29 35 31 28 27 31 33 34 26 32 29 32 28
#  31 34 31 31 35 33 29 30 27 25 33 29 28 31 28 26 26 29 30 29 32 30 27 24
#  33 29 32 36 28 28 33 33 32 31 28 26 32 31 25 28 27 29 28 33 35 30 33 33
#  27 29 29 33 26 29 33 35 26 28 29 30 33 29 36 34 33 35 33 26 29 34 32 30
#  28 26 30 26 28 26 26 30]

# %%
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0][0]
skew = stats.skew(data)
kurtosis = stats.kurtosis(data)


print("Mean : ",mean)
print("Median : ",median)
print("Mode : ",mode)
print("Skew : ",skew)
print("Kurtosis : ",kurtosis)
# Out:
# Mean :  29.99
# Median :  30.0
# Mode :  29
# Skew :  0.04230781209847587
# Kurtosis :  -0.44173569409639324
# C:\Users\HIGH COMP\AppData\Local\Temp\ipykernel_10784\3001336844.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(data)[0][0]

# %%
plt.hist(x=data,bins = 'auto', alpha = 0.9 , rwidth=0.95 , facecolor = 'yellow' , edgecolor = 'black')

plt.axvline(mean , color = 'r' , linestyle = 'dashed' , linewidth = 1)
plt.axvline(median , color = 'g' , linestyle = 'dashed' , linewidth = 1)
plt.axvline(mode , color = 'b' , linestyle = 'dashed' , linewidth = 1)
plt.text(mean ,40, f'Mean:{mean:.2f}' , color = 'r')
plt.text(median , 45 , f'Median:{median:.2f}',color = 'g')
plt.text(mode,50,f'Mode:{mode:.2f}',color = 'b')


plt.grid(axis='y',alpha=0.75)
plt.ylim(ymax=80)
plt.xlim(xmax=80)
plt.show()

# %%
data1 = [33,25,60,99,45,67,22,55,85,30]
data2 = np.random.normal(size=200,scale=5,loc=0)
data3 = stats.bernoulli.rvs(size=100,p=0.5,loc=25)
data4 = stats.binom.rvs(size=200,p=0.5,n=100,loc=0)
data5 = stats.multinomial.rvs(size=200,p=[0.5,0.5],n=250)
data6 = stats.poisson.rvs(size=200,mu=10,loc=160)



print("Data1 :\n" , data1,"\n",100*"*")
print("Data2 :\n" , data2,"\n",100*"*")
print("Data3 :\n" , data3,"\n",100*"*")
print("Data4 :\n" , data4,"\n",100*"*")
print("Data5 :\n" , data5,"\n",100*"*")
print("Data6 :\n" , data6,"\n",100*"*")
# Out:
# Data1 :
#  [33, 25, 60, 99, 45, 67, 22, 55, 85, 30]
#  ****************************************************************************************************
# Data2 :
#  [  0.23254229 -12.41924582   1.42059694  -3.66626325   2.86019239
#    2.1086471   -1.24423363  -6.50935267   0.67530376  -4.59502866
#   -6.88413217   7.09059296  -4.90397655  -0.13596304  -1.14139698
#   -1.62800894  -1.85136859  -3.8934008   -8.20126099   0.87289576
#   -1.53234236   2.96097657   3.5513573   -3.10912065   6.16222929
#    3.23911547  -3.33979429   5.83779933  -7.45226258  -2.97263753
#   -3.44942466  -3.648819    -2.13220628  -4.75992018  -7.97557073
#   -0.49203573   3.02040221   3.42871204  -1.75203097   7.809813
#   -0.74707309  -2.55306744 -20.40145149   0.93744106   2.96549074
#    1.82385429  -7.98914795 -10.43372613   1.16367143  -2.65224831
#   -0.57486159   1.8959154   -0.4341672   -0.75612909  -3.76180346
#    9.36610139   1.9707612   -0.28342598   3.80885853   7.18211248
# ...
